# %%
import numpy as np

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Telco-Customer-Churn.csv")
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2248  9554-DFKIC    Male              0     Yes        Yes      30
# 5213  7668-XCFYV  Female              1     Yes         No      17
# 5295  2144-BFDSO  Female              1     Yes         No      50
# 4495  4702-IOQDC  Female              0      No         No       1
# 3778  9631-XEYKE    Male              0      No         No       3
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 2248          Yes           Yes             DSL            Yes  ...
# 5213          Yes           Yes     Fiber optic             No  ...
# 5295          Yes           Yes     Fiber optic            Yes  ...
# 4495          Yes            No     Fiber optic             No  ...
# 3778          Yes           Yes             DSL             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 2248               No          No          No              No  Month-to-month
# 5213               No          No         Yes             Yes  Month-to-month
# 5295              Yes          No         Yes             Yes  Month-to-month
# 4495               No          No          No              No  Month-to-month
# 3778               No          No          No              No  Month-to-month
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 2248              Yes  Bank transfer (automatic)          54.45        1588.7
# 5213              Yes           Electronic check          92.55        1614.7
# 5295               No  Bank transfer (automatic)         108.75        5431.9
# 4495              Yes           Electronic check          70.10          70.1
# 3778               No  Bank transfer (automatic)          50.40        137.25
#
#      Churn
# 2248    No
# 5213    No
# 5295    No
# 4495   Yes
# 3778    No
#
# [5 rows x 21 columns]

# %%
df.drop('customerID', axis='columns', inplace=True)

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)
